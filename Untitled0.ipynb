# %%
files = ['a_example.txt', 'b_read_on.txt', 'c_incunabula.txt', 'd_tough_choices.txt', 'e_so_many_books.txt', 'f_libraries_of_the_world.txt']
f = open('data/' + files[4])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-aa147e5019b7> in <module>()
#       1 files = ['a_example.txt', 'b_read_on.txt', 'c_incunabula.txt', 'd_tough_choices.txt', 'e_so_many_books.txt', 'f_libraries_of_the_world.txt']
# ----> 2 f = open('data/' + files[4])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/e_so_many_books.txt'

# %%
B, L, D = list(map(int, f.readline().split()))
S = list(map(int, f.readline().split()))
print("Book:", B)
print("Lib:", L)
print("Days:", D)

# %%
Nl = []
Tl = []
Ml = []
IDl = []
for i in range(L):
    N, T, M = list(map(int, f.readline().split()))
    Nl.append(N)
    Tl.append(T)
    Ml.append(M)
    IDs = list(map(int, f.readline().split()))
    IDl.append(IDs)
f.close()
